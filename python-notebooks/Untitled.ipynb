# %%
from futuremakers import*

# %%
test_futuremakers()
# Out:
# The FutureMakers library is imported and ready to use.

# %%
translate_english_to_spanish('I have a very good dog')
# Out:
# 'Tengo un perro muy bueno.'

# %%
translate( 'en', 'fr', 'I have a very good dog')
# Out:
# "J'ai un très bon chien"

# %%
translate('fr','es', "J'ai un bon chien")
# Out:
# 'Tengo un buen perro.'

# %% [raw]
# translate('es', 'en', 'Tengo un buen perro.')

# %%
speak ('Big four times')
# Out:
# File saved as polly\Bigfouraad76.mp3.

# %%
show_image('images/Big four times.jpg')

# %%
find_celebrities('images/trevor.jpg')
# Out:
# Amazon Rekognition found one celebrity in images/patrick_stewart.jpg: Patrick Stewart.
# 'Amazon Rekognition found one celebrity in images/patrick_stewart.jpg: Patrick Stewart.'

# %%
show_image('images/trevor.jpg')

# %%
detect_faces()
