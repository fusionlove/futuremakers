# %%
from futuremakers import *

# %%
test_futuremakers()
# Out:
# The FutureMakers library is imported and ready to use.

# %%
translate_english_to_spanish("I am enjoying this workshop!")
# Out:
# '¡Estoy disfrutando de este taller!'

# %%
# This will create an mp3 in the polly folder, and play it
speak('Hello from London!')
# Out:
# File saved as polly/Hellofrom09735.mp3.

# %%
show_image('images/friends.jpg')

# %%
find_celebrities('images/friends.jpg')
# Out:
# Amazon Rekognition found one celebrity in images/friends.jpg: David Schwimmer.
# 'Amazon Rekognition found one celebrity in images/friends.jpg: David Schwimmer.'

# %%
show_image('images/patrick_stewart.jpg')

# %%
detect_faces('images/friends.jpg')
# Out:
# Amazon Rekognition found 6 faces in this image.
# I think this person is between 29 and 45 years old. I am 56 percent sure that they do not have a beard. I am 99 percent sure that they are feeling surprised.
# I think this person is between 23 and 35 years old. I am 72 percent sure that they do not have a beard. I am 99 percent sure that they are feeling happy.
# I think this person is between 23 and 35 years old. I am 66 percent sure that they do not have a beard. I am 97 percent sure that they are feeling happy.
# I think this person is between 26 and 40 years old. I am 55 percent sure that they do not have a beard. I am 55 percent sure that they are feeling happy.
# I think this person is between 26 and 42 years old. I am 55 percent sure that they do not have a beard. I am 54 percent sure that they are feeling happy.
# I think this person is between 23 and 35 years old. I am 55 percent sure that they do not have a beard. I am 55 percent sure that they are feeling happy.

# %%
show_image('images/mike_wilks.jpg')

# %%
detect_objects('images/friends.jpg')
# Out:
# Amazon Rekognition found 38 objects in images/friends.jpg.
# The objects are:
# I am 100 percent sure that I see a dating.
# I am 100 percent sure that I see a human.
# I am 100 percent sure that I see a person.
# I am 99 percent sure that I see a woman.
# I am 99 percent sure that I see a teen.
# I am 99 percent sure that I see a child.
# I am 99 percent sure that I see a kid.
# I am 99 percent sure that I see a blonde.
# I am 99 percent sure that I see a female.
# I am 99 percent sure that I see a girl.
# I am 98 percent sure that I see a apparel.
# I am 98 percent sure that I see a coat.
# I am 98 percent sure that I see a suit.
# I am 98 percent sure that I see a clothing.
# I am 98 percent sure that I see a overcoat.
# I am 98 percent sure that I see a face.
# I am 94 percent sure that I see a smile.
# I am 85 percent sure that I see a people.
# I am 71 percent sure that I see a tuxedo.
# I am 65 percent sure that I see a blazer.
# I am 65 percent sure that I see a jacket.
# ...

# %%
translate('en', 'fr', 'I have a good dog')
# Out:
# "J'ai un bon chien."

# %%
translate('fr', 'en', "J'ai un bon chien.")
# Out:
# 'I got a good dog.'
